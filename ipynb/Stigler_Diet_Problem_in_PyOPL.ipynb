# %% [markdown]
# # Stigler's Diet Problem
#
# In this section, we show how to solve a classic problem called the
# [Stigler diet](http://en.wikipedia.org/wiki/Stigler_diet), named for economics
# Nobel laureate George Stigler, who computed an inexpensive way to fulfill basic
# nutritional needs given a set of foods. He posed this as a mathematical exercise
# , not as eating recommendations, although the notion of computing optimal
# nutrition has of [come into vogue](http://en.wikipedia.org/wiki/CRON-diet)
# recently.
#
# The Stigler diet mandated that these minimums be met:
#
# <details>
# <summary><h4>Nutrients list</h4></summary>
#
# | Nutrient | Daily Recommended Intake |
# |---|---|
# | Calories | 3,000 calories |
# | Protein | 70 grams |
# | Calcium | .8 grams |
# | Iron | 12 milligrams |
# | Vitamin A | 5,000 IU |
# | Thiamine (Vitamin B1) | 1.8 milligrams |
# | Riboflavin (Vitamin B2) | 2.7 milligrams |
# | Niacin | 18 milligrams |
# | Ascorbic Acid (Vitamin C) | 75 milligrams |
#
# </details>
#
# The set of foods Stigler evaluated was a reflection of the time
# (1944). The nutritional data below is per dollar, not per unit, so the
# objective is to determine how many dollars to spend on each foodstuff.
#
# <details>
# <summary><h4>Commodities list</h4></summary>
#
# | Commodity | Unit | 1939 price (cents) | Calories (kcal) | Protein (g) | Calcium (g) | Iron (mg) | Vitamin A (KIU) | Thiamine (mg) | Riboflavin (mg) | Niacin (mg) | Ascorbic Acid (mg) |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | Wheat Flour (Enriched) | 10 lb. | 36 | 44.7 | 1411 | 2 | 365 | 0 | 55.4 | 33.3 | 441 | 0 |
# | Macaroni | 1 lb. | 14.1 | 11.6 | 418 | 0.7 | 54 | 0 | 3.2 | 1.9 | 68 | 0 |
# | Wheat Cereal (Enriched) | 28 oz. | 24.2 | 11.8 | 377 | 14.4 | 175 | 0 | 14.4 | 8.8 | 114 | 0 |
# | Corn Flakes | 8 oz. | 7.1 | 11.4 | 252 | 0.1 | 56 | 0 | 13.5 | 2.3 | 68 | 0 |
# | Corn Meal | 1 lb. | 4.6 | 36.0 | 897 | 1.7 | 99 | 30.9 | 17.4 | 7.9 | 106 | 0 |
# | Hominy Grits | 24 oz. | 8.5 | 28.6 | 680 | 0.8 | 80 | 0 | 10.6 | 1.6 | 110 | 0 |
# | Rice | 1 lb. | 7.5 | 21.2 | 460 | 0.6 | 41 | 0 | 2 | 4.8 | 60 | 0 |
# | Rolled Oats | 1 lb. | 7.1 | 25.3 | 907 | 5.1 | 341 | 0 | 37.1 | 8.9 | 64 | 0 |
# | White Bread (Enriched) | 1 lb. | 7.9 | 15.0 | 488 | 2.5 | 115 | 0 | 13.8 | 8.5 | 126 | 0 |
# | Whole Wheat Bread | 1 lb. | 9.1 | 12.2 | 484 | 2.7 | 125 | 0 | 13.9 | 6.4 | 160 | 0 |
# | Rye Bread | 1 lb. | 9.1 | 12.4 | 439 | 1.1 | 82 | 0 | 9.9 | 3 | 66 | 0 |
# | Pound Cake | 1 lb. | 24.8 | 8.0 | 130 | 0.4 | 31 | 18.9 | 2.8 | 3 | 17 | 0 |
# | Soda Crackers | 1 lb. | 15.1 | 12.5 | 288 | 0.5 | 50 | 0 | 0 | 0 | 0 | 0 |
# | Milk | 1 qt. | 11 | 6.1 | 310 | 10.5 | 18 | 16.8 | 4 | 16 | 7 | 177 |
# | Evaporated Milk (can) | 14.5 oz. | 6.7 | 8.4 | 422 | 15.1 | 9 | 26 | 3 | 23.5 | 11 | 60 |
# | Butter | 1 lb. | 30.8 | 10.8 | 9 | 0.2 | 3 | 44.2 | 0 | 0.2 | 2 | 0 |
# | Oleomargarine | 1 lb. | 16.1 | 20.6 | 17 | 0.6 | 6 | 55.8 | 0.2 | 0 | 0 | 0 |
# | Eggs | 1 doz. | 32.6 | 2.9 | 238 | 1.0 | 52 | 18.6 | 2.8 | 6.5 | 1 | 0 |
# | Cheese (Cheddar) | 1 lb. | 24.2 | 7.4 | 448 | 16.4 | 19 | 28.1 | 0.8 | 10.3 | 4 | 0 |
# | Cream | 1/2 pt. | 14.1 | 3.5 | 49 | 1.7 | 3 | 16.9 | 0.6 | 2.5 | 0 | 17 |
# | Peanut Butter | 1 lb. | 17.9 | 15.7 | 661 | 1.0 | 48 | 0 | 9.6 | 8.1 | 471 | 0 |
# | Mayonnaise | 1/2 pt. | 16.7 | 8.6 | 18 | 0.2 | 8 | 2.7 | 0.4 | 0.5 | 0 | 0 |
# | Crisco | 1 lb. | 20.3 | 20.1 | 0 | 0 | 0 | 0 | 0 | 0 | 0 | 0 |
# | Lard | 1 lb. | 9.8 | 41.7 | 0 | 0 | 0 | 0.2 | 0 | 0.5 | 5 | 0 |
# | Sirloin Steak | 1 lb. | 39.6 | 2.9 | 166 | 0.1 | 34 | 0.2 | 2.1 | 2.9 | 69 | 0 |
# | Round Steak | 1 lb. | 36.4 | 2.2 | 214 | 0.1 | 32 | 0.4 | 2.5 | 2.4 | 87 | 0 |
# | Rib Roast | 1 lb. | 29.2 | 3.4 | 213 | 0.1 | 33 | 0 | 0 | 2 | 0 | 0 |
# | Chuck Roast | 1 lb. | 22.6 | 3.6 | 309 | 0.2 | 46 | 0.4 | 1 | 4 | 120 | 0 |
# | Plate | 1 lb. | 14.6 | 8.5 | 404 | 0.2 | 62 | 0 | 0.9 | 0 | 0 | 0 |
# | Liver (Beef) | 1 lb. | 26.8 | 2.2 | 333 | 0.2 | 139 | 169.2 | 6.4 | 50.8 | 316 | 525 |
# | Leg of Lamb | 1 lb. | 27.6 | 3.1 | 245 | 0.1 | 20 | 0 | 2.8 | 3.9 | 86 | 0 |
# | Lamb Chops (Rib) | 1 lb. | 36.6 | 3.3 | 140 | 0.1 | 15 | 0 | 1.7 | 2.7 | 54 | 0 |
# | Pork Chops | 1 lb. | 30.7 | 3.5 | 196 | 0.2 | 30 | 0 | 17.4 | 2.7 | 60 | 0 |
# | Pork Loin Roast | 1 lb. | 24.2 | 4.4 | 249 | 0.3 | 37 | 0 | 18.2 | 3.6 | 79 | 0 |
# | Bacon | 1 lb. | 25.6 | 10.4 | 152 | 0.2 | 23 | 0 | 1.8 | 1.8 | 71 | 0 |
# | Ham, smoked | 1 lb. | 27.4 | 6.7 | 212 | 0.2 | 31 | 0 | 9.9 | 3.3 | 50 | 0 |
# | Salt Pork | 1 lb. | 16 | 18.8 | 164 | 0.1 | 26 | 0 | 1.4 | 1.8 | 0 | 0 |
# | Roasting Chicken | 1 lb. | 30.3 | 1.8 | 184 | 0.1 | 30 | 0.1 | 0.9 | 1.8 | 68 | 46 |
# | Veal Cutlets | 1 lb. | 42.3 | 1.7 | 156 | 0.1 | 24 | 0 | 1.4 | 2.4 | 57 | 0 |
# | Salmon, Pink (can) | 16 oz. | 13 | 5.8 | 705 | 6.8 | 45 | 3.5 | 1 | 4.9 | 209 | 0 |
# | Apples | 1 lb. | 4.4 | 5.8 | 27 | 0.5 | 36 | 7.3 | 3.6 | 2.7 | 5 | 544 |
# | Bananas | 1 lb. | 6.1 | 4.9 | 60 | 0.4 | 30 | 17.4 | 2.5 | 3.5 | 28 | 498 |
# | Lemons | 1 doz. | 26 | 1.0 | 21 | 0.5 | 14 | 0 | 0.5 | 0 | 4 | 952 |
# | Oranges | 1 doz. | 30.9 | 2.2 | 40 | 1.1 | 18 | 11.1 | 3.6 | 1.3 | 10 | 1998 |
# | Green Beans | 1 lb. | 7.1 | 2.4 | 138 | 3.7 | 80 | 69 | 4.3 | 5.8 | 37 | 862 |
# | Cabbage | 1 lb. | 3.7 | 2.6 | 125 | 4.0 | 36 | 7.2 | 9 | 4.5 | 26 | 5369 |
# | Carrots | 1 bunch | 4.7 | 2.7 | 73 | 2.8 | 43 | 188.5 | 6.1 | 4.3 | 89 | 608 |
# | Celery | 1 stalk | 7.3 | 0.9 | 51 | 3.0 | 23 | 0.9 | 1.4 | 1.4 | 9 | 313 |
# | Lettuce | 1 head | 8.2 | 0.4 | 27 | 1.1 | 22 | 112.4 | 1.8 | 3.4 | 11 | 449 |
# | Onions | 1 lb. | 3.6 | 5.8 | 166 | 3.8 | 59 | 16.6 | 4.7 | 5.9 | 21 | 1184 |
# | Potatoes | 15 lb. | 34 | 14.3 | 336 | 1.8 | 118 | 6.7 | 29.4 | 7.1 | 198 | 2522 |
# | Spinach | 1 lb. | 8.1 | 1.1 | 106 | 0 | 138 | 918.4 | 5.7 | 13.8 | 33 | 2755 |
# | Sweet Potatoes | 1 lb. | 5.1 | 9.6 | 138 | 2.7 | 54 | 290.7 | 8.4 | 5.4 | 83 | 1912 |
# | Peaches (can) | No. 2 1/2 | 16.8 | 3.7 | 20 | 0.4 | 10 | 21.5 | 0.5 | 1 | 31 | 196 |
# | Pears (can) | No. 2 1/2 | 20.4 | 3.0 | 8 | 0.3 | 8 | 0.8 | 0.8 | 0.8 | 5 | 81 |
# | Pineapple (can) | No. 2 1/2 | 21.3 | 2.4 | 16 | 0.4 | 8 | 2 | 2.8 | 0.8 | 7 | 399 |
# | Asparagus (can) | No. 2 | 27.7 | 0.4 | 33 | 0.3 | 12 | 16.3 | 1.4 | 2.1 | 17 | 272 |
# | Green Beans (can) | No. 2 | 10 | 1.0 | 54 | 2 | 65 | 53.9 | 1.6 | 4.3 | 32 | 431 |
# | Pork and Beans (can) | 16 oz. | 7.1 | 7.5 | 364 | 4 | 134 | 3.5 | 8.3 | 7.7 | 56 | 0 |
# | Corn (can) | No. 2 | 10.4 | 5.2 | 136 | 0.2 | 16 | 12 | 1.6 | 2.7 | 42 | 218 |
# | Peas (can) | No. 2 | 13.8 | 2.3 | 136 | 0.6 | 45 | 34.9 | 4.9 | 2.5 | 37 | 370 |
# | Tomatoes (can) | No. 2 | 8.6 | 1.3 | 63 | 0.7 | 38 | 53.2 | 3.4 | 2.5 | 36 | 1253 |
# | Tomato Soup (can) | 10 1/2 oz. | 7.6 | 1.6 | 71 | 0.6 | 43 | 57.9 | 3.5 | 2.4 | 67 | 862 |
# | Peaches, Dried | 1 lb. | 15.7 | 8.5 | 87 | 1.7 | 173 | 86.8 | 1.2 | 4.3 | 55 | 57 |
# | Prunes, Dried | 1 lb. | 9 | 12.8 | 99 | 2.5 | 154 | 85.7 | 3.9 | 4.3 | 65 | 257 |
# | Raisins, Dried | 15 oz. | 9.4 | 13.5 | 104 | 2.5 | 136 | 4.5 | 6.3 | 1.4 | 24 | 136 |
# | Peas, Dried | 1 lb. | 7.9 | 20.0 | 1367 | 4.2 | 345 | 2.9 | 28.7 | 18.4 | 162 | 0 |
# | Lima Beans, Dried | 1 lb. | 8.9 | 17.4 | 1055 | 3.7 | 459 | 5.1 | 26.9 | 38.2 | 93 | 0 |
# | Navy Beans, Dried | 1 lb. | 5.9 | 26.9 | 1691 | 11.4 | 792 | 0 | 38.4 | 24.6 | 217 | 0 |
# | Coffee | 1 lb. | 22.4 | 0 | 0 | 0 | 0 | 0 | 4 | 5.1 | 50 | 0 |
# | Tea | 1/4 lb. | 17.4 | 0 | 0 | 0 | 0 | 0 | 0 | 2.3 | 42 | 0 |
# | Cocoa | 8 oz. | 8.6 | 8.7 | 237 | 3 | 72 | 0 | 2 | 11.9 | 40 | 0 |
# | Chocolate | 8 oz. | 16.2 | 8.0 | 77 | 1.3 | 39 | 0 | 0.9 | 3.4 | 14 | 0 |
# | Sugar | 10 lb. | 51.7 | 34.9 | 0 | 0 | 0 | 0 | 0 | 0 | 0 | 0 |
# | Corn Syrup | 24 oz. | 13.7 | 14.7 | 0 | 0.5 | 74 | 0 | 0 | 0 | 5 | 0 |
# | Molasses | 18 oz. | 13.6 | 9.0 | 0 | 10.3 | 244 | 0 | 1.9 | 7.5 | 146 | 0 |
# | Strawberry Preserves | 1 lb. | 20.5 | 6.4 | 11 | 0.4 | 7 | 0.2 | 0.2 | 0.4 | 3 | 0 |
#
# </details>
#
# Since the nutrients have all been normalized by price, our objective is simply
# minimizing the sum of foods.
#
# In 1944, Stigler calculated the best answer he could, noting with sadness:
# > ...there does not appear to be any direct method of finding the minimum of a
# > linear function subject to linear conditions.
#
# He found a diet that cost $39.93 per year, in 1939 dollars. In 1947, Jack
# Laderman used the simplex method (then, a recent invention!) to determine the
# optimal solution. It took 120 man days of nine clerks on desk calculators to
# arrive at the answer.

# %% [markdown]
# ## Solution using PyOPL
#
# The following sections present a program that solves the Stigler diet problem.

# %%
pyopl_model = '''
// Stigler's Diet Problem (LP)
// ------------------------
// Choose nonnegative daily quantities of foods to satisfy minimum nutrient requirements
// at minimum daily cost.
//
// https://developers.google.com/optimization/lp/stigler_diet

// -----------------------------
// Sets (provided in .dat)
// -----------------------------
{string} Foods = ...;                  // Food identifiers (names)
{string} Nutrients = ...;              // Nutrient identifiers (names)

// -----------------------------
// Parameters (provided in .dat)
// -----------------------------
param float minDailyReq[Nutrients] = ...;   // minReq[n] = minimum required intake of nutrient n (per day)
param float a[Nutrients][Foods] = ...; // a[n][f]   = amount of nutrient n provided by 1 unit of food f

// -----------------------------
// Decision variables
// -----------------------------
dvar float+ x[Foods];                  // x[f] = units of food f purchased/consumed per year (continuous, >= 0)
dvar float+ y[Nutrients];              // y[n] = total daily intake of nutrient n from chosen foods

// -----------------------------
// Decision expressions
// -----------------------------
dexpr float achieved[n in Nutrients] =  // achieved[n] = total daily intake of nutrient n from chosen foods
  sum(f in Foods) a[n][f] * x[f]/365;

// -----------------------------
// Objective
// -----------------------------
minimize TotalCost:                    // (OBJ) Minimize total annual cost. 
  sum(f in Foods) x[f];                // The nutritional data is per dollar, not per unit, so the objective 
                                       // is to determine how many dollars to spend on each foodstuff.

// -----------------------------
// Constraints
// -----------------------------
subject to {
  // (C1) Nutrient minimums: for each nutrient n, achieved intake must meet minDailyReq[n]
  forall(n in Nutrients){
    NutrientMinimum:
      achieved[n] >= minDailyReq[n];
      y[n] == achieved[n];
  }
}
'''

# %%
pyopl_data = '''
Foods = {
  "Wheat Flour (Enriched)",
  "Macaroni",
  "Wheat Cereal (Enriched)",
  "Corn Flakes",
  "Corn Meal",
  "Hominy Grits",
  "Rice",
  "Rolled Oats",
  "White Bread (Enriched)",
  "Whole Wheat Bread",
  "Rye Bread",
  "Pound Cake",
  "Soda Crackers",
  "Milk",
  "Evaporated Milk (can)",
  "Butter",
  "Oleomargarine",
  "Eggs",
  "Cheese (Cheddar)",
  "Cream",
  "Peanut Butter",
  "Mayonnaise",
  "Crisco",
  "Lard",
  "Sirloin Steak",
  "Round Steak",
  "Rib Roast",
  "Chuck Roast",
  "Plate",
  "Liver (Beef)",
  "Leg of Lamb",
  "Lamb Chops (Rib)",
  "Pork Chops",
  "Pork Loin Roast",
  "Bacon",
  "Ham, smoked",
  "Salt Pork",
  "Roasting Chicken",
  "Veal Cutlets",
  "Salmon, Pink (can)",
  "Apples",
  "Bananas",
  "Lemons",
  "Oranges",
  "Green Beans",
  "Cabbage",
  "Carrots",
  "Celery",
  "Lettuce",
  "Onions",
  "Potatoes",
  "Spinach",
  "Sweet Potatoes",
  "Peaches (can)",
  "Pears (can)",
  "Pineapple (can)",
  "Asparagus (can)",
  "Green Beans (can)",
  "Pork and Beans (can)",
  "Corn (can)",
  "Peas (can)",
  "Tomatoes (can)",
  "Tomato Soup (can)",
  "Peaches, Dried",
  "Prunes, Dried",
  "Raisins, Dried",
  "Peas, Dried",
  "Lima Beans, Dried",
  "Navy Beans, Dried",
  "Coffee",
  "Tea",
  "Cocoa",
  "Chocolate",
  "Sugar",
  "Corn Syrup",
  "Molasses",
  "Strawberry Preserves"
};

Nutrients = {
  "Calories (kcal)",
  "Protein (g)",
  "Calcium (g)",
  "Iron (mg)",
  "Vitamin A (KIU)",
  "Vitamin B1 (mg)",
  "Vitamin B2 (mg)",
  "Niacin (mg)",
  "Vitamin C (mg)"
};

// The Stigler diet mandated that these minimums be met per day:
minDailyReq = [
  "Calories (kcal)" 3,
  "Protein (g)" 70,
  "Calcium (g)" 0.8,
  "Iron (mg)" 12,
  "Vitamin A (KIU)" 5,
  "Vitamin B1 (mg)" 1.8,
  "Vitamin B2 (mg)" 2.7,
  "Niacin (mg)" 18,
  "Vitamin C (mg)" 75
];

// The nutritional data below is per dollar, not per unit, so the objective is to 
// determine how many dollars to spend on each foodstuff.
a = [
  <"Calories (kcal)","Wheat Flour (Enriched)"> 44.7,
  <"Protein (g)","Wheat Flour (Enriched)"> 1411,
  <"Calcium (g)","Wheat Flour (Enriched)"> 2,
  <"Iron (mg)","Wheat Flour (Enriched)"> 365,
  <"Vitamin A (KIU)","Wheat Flour (Enriched)"> 0,
  <"Vitamin B1 (mg)","Wheat Flour (Enriched)"> 55.4,
  <"Vitamin B2 (mg)","Wheat Flour (Enriched)"> 33.3,
  <"Niacin (mg)","Wheat Flour (Enriched)"> 441,
  <"Vitamin C (mg)","Wheat Flour (Enriched)"> 0,

  <"Calories (kcal)","Macaroni"> 11.6,
  <"Protein (g)","Macaroni"> 418,
  <"Calcium (g)","Macaroni"> 0.7,
  <"Iron (mg)","Macaroni"> 54,
  <"Vitamin A (KIU)","Macaroni"> 0,
  <"Vitamin B1 (mg)","Macaroni"> 3.2,
  <"Vitamin B2 (mg)","Macaroni"> 1.9,
  <"Niacin (mg)","Macaroni"> 68,
  <"Vitamin C (mg)","Macaroni"> 0,

  <"Calories (kcal)","Wheat Cereal (Enriched)"> 11.8,
  <"Protein (g)","Wheat Cereal (Enriched)"> 377,
  <"Calcium (g)","Wheat Cereal (Enriched)"> 14.4,
  <"Iron (mg)","Wheat Cereal (Enriched)"> 175,
  <"Vitamin A (KIU)","Wheat Cereal (Enriched)"> 0,
  <"Vitamin B1 (mg)","Wheat Cereal (Enriched)"> 14.4,
  <"Vitamin B2 (mg)","Wheat Cereal (Enriched)"> 8.8,
  <"Niacin (mg)","Wheat Cereal (Enriched)"> 114,
  <"Vitamin C (mg)","Wheat Cereal (Enriched)"> 0,

  <"Calories (kcal)","Corn Flakes"> 11.4,
  <"Protein (g)","Corn Flakes"> 252,
  <"Calcium (g)","Corn Flakes"> 0.1,
  <"Iron (mg)","Corn Flakes"> 56,
  <"Vitamin A (KIU)","Corn Flakes"> 0,
  <"Vitamin B1 (mg)","Corn Flakes"> 13.5,
  <"Vitamin B2 (mg)","Corn Flakes"> 2.3,
  <"Niacin (mg)","Corn Flakes"> 68,
  <"Vitamin C (mg)","Corn Flakes"> 0,

  <"Calories (kcal)","Corn Meal"> 36.0,
  <"Protein (g)","Corn Meal"> 897,
  <"Calcium (g)","Corn Meal"> 1.7,
  <"Iron (mg)","Corn Meal"> 99,
  <"Vitamin A (KIU)","Corn Meal"> 30.9,
  <"Vitamin B1 (mg)","Corn Meal"> 17.4,
  <"Vitamin B2 (mg)","Corn Meal"> 7.9,
  <"Niacin (mg)","Corn Meal"> 106,
  <"Vitamin C (mg)","Corn Meal"> 0,

  <"Calories (kcal)","Hominy Grits"> 28.6,
  <"Protein (g)","Hominy Grits"> 680,
  <"Calcium (g)","Hominy Grits"> 0.8,
  <"Iron (mg)","Hominy Grits"> 80,
  <"Vitamin A (KIU)","Hominy Grits"> 0,
  <"Vitamin B1 (mg)","Hominy Grits"> 10.6,
  <"Vitamin B2 (mg)","Hominy Grits"> 1.6,
  <"Niacin (mg)","Hominy Grits"> 110,
  <"Vitamin C (mg)","Hominy Grits"> 0,

  <"Calories (kcal)","Rice"> 21.2,
  <"Protein (g)","Rice"> 460,
  <"Calcium (g)","Rice"> 0.6,
  <"Iron (mg)","Rice"> 41,
  <"Vitamin A (KIU)","Rice"> 0,
  <"Vitamin B1 (mg)","Rice"> 2,
  <"Vitamin B2 (mg)","Rice"> 4.8,
  <"Niacin (mg)","Rice"> 60,
  <"Vitamin C (mg)","Rice"> 0,

  <"Calories (kcal)","Rolled Oats"> 25.3,
  <"Protein (g)","Rolled Oats"> 907,
  <"Calcium (g)","Rolled Oats"> 5.1,
  <"Iron (mg)","Rolled Oats"> 341,
  <"Vitamin A (KIU)","Rolled Oats"> 0,
  <"Vitamin B1 (mg)","Rolled Oats"> 37.1,
  <"Vitamin B2 (mg)","Rolled Oats"> 8.9,
  <"Niacin (mg)","Rolled Oats"> 64,
  <"Vitamin C (mg)","Rolled Oats"> 0,

  <"Calories (kcal)","White Bread (Enriched)"> 15.0,
  <"Protein (g)","White Bread (Enriched)"> 488,
  <"Calcium (g)","White Bread (Enriched)"> 2.5,
  <"Iron (mg)","White Bread (Enriched)"> 115,
  <"Vitamin A (KIU)","White Bread (Enriched)"> 0,
  <"Vitamin B1 (mg)","White Bread (Enriched)"> 13.8,
  <"Vitamin B2 (mg)","White Bread (Enriched)"> 8.5,
  <"Niacin (mg)","White Bread (Enriched)"> 126,
  <"Vitamin C (mg)","White Bread (Enriched)"> 0,

  <"Calories (kcal)","Whole Wheat Bread"> 12.2,
  <"Protein (g)","Whole Wheat Bread"> 484,
  <"Calcium (g)","Whole Wheat Bread"> 2.7,
  <"Iron (mg)","Whole Wheat Bread"> 125,
  <"Vitamin A (KIU)","Whole Wheat Bread"> 0,
  <"Vitamin B1 (mg)","Whole Wheat Bread"> 13.9,
  <"Vitamin B2 (mg)","Whole Wheat Bread"> 6.4,
  <"Niacin (mg)","Whole Wheat Bread"> 160,
  <"Vitamin C (mg)","Whole Wheat Bread"> 0,

  <"Calories (kcal)","Rye Bread"> 12.4,
  <"Protein (g)","Rye Bread"> 439,
  <"Calcium (g)","Rye Bread"> 1.1,
  <"Iron (mg)","Rye Bread"> 82,
  <"Vitamin A (KIU)","Rye Bread"> 0,
  <"Vitamin B1 (mg)","Rye Bread"> 9.9,
  <"Vitamin B2 (mg)","Rye Bread"> 3,
  <"Niacin (mg)","Rye Bread"> 66,
  <"Vitamin C (mg)","Rye Bread"> 0,

  <"Calories (kcal)","Pound Cake"> 8.0,
  <"Protein (g)","Pound Cake"> 130,
  <"Calcium (g)","Pound Cake"> 0.4,
  <"Iron (mg)","Pound Cake"> 31,
  <"Vitamin A (KIU)","Pound Cake"> 18.9,
  <"Vitamin B1 (mg)","Pound Cake"> 2.8,
  <"Vitamin B2 (mg)","Pound Cake"> 3,
  <"Niacin (mg)","Pound Cake"> 17,
  <"Vitamin C (mg)","Pound Cake"> 0,

  <"Calories (kcal)","Soda Crackers"> 12.5,
  <"Protein (g)","Soda Crackers"> 288,
  <"Calcium (g)","Soda Crackers"> 0.5,
  <"Iron (mg)","Soda Crackers"> 50,
  <"Vitamin A (KIU)","Soda Crackers"> 0,
  <"Vitamin B1 (mg)","Soda Crackers"> 0,
  <"Vitamin B2 (mg)","Soda Crackers"> 0,
  <"Niacin (mg)","Soda Crackers"> 0,
  <"Vitamin C (mg)","Soda Crackers"> 0,

  <"Calories (kcal)","Milk"> 6.1,
  <"Protein (g)","Milk"> 310,
  <"Calcium (g)","Milk"> 10.5,
  <"Iron (mg)","Milk"> 18,
  <"Vitamin A (KIU)","Milk"> 16.8,
  <"Vitamin B1 (mg)","Milk"> 4,
  <"Vitamin B2 (mg)","Milk"> 16,
  <"Niacin (mg)","Milk"> 7,
  <"Vitamin C (mg)","Milk"> 177,

  <"Calories (kcal)","Evaporated Milk (can)"> 8.4,
  <"Protein (g)","Evaporated Milk (can)"> 422,
  <"Calcium (g)","Evaporated Milk (can)"> 15.1,
  <"Iron (mg)","Evaporated Milk (can)"> 9,
  <"Vitamin A (KIU)","Evaporated Milk (can)"> 26,
  <"Vitamin B1 (mg)","Evaporated Milk (can)"> 3,
  <"Vitamin B2 (mg)","Evaporated Milk (can)"> 23.5,
  <"Niacin (mg)","Evaporated Milk (can)"> 11,
  <"Vitamin C (mg)","Evaporated Milk (can)"> 60,

  <"Calories (kcal)","Butter"> 10.8,
  <"Protein (g)","Butter"> 9,
  <"Calcium (g)","Butter"> 0.2,
  <"Iron (mg)","Butter"> 3,
  <"Vitamin A (KIU)","Butter"> 44.2,
  <"Vitamin B1 (mg)","Butter"> 0,
  <"Vitamin B2 (mg)","Butter"> 0.2,
  <"Niacin (mg)","Butter"> 2,
  <"Vitamin C (mg)","Butter"> 0,

  <"Calories (kcal)","Oleomargarine"> 20.6,
  <"Protein (g)","Oleomargarine"> 17,
  <"Calcium (g)","Oleomargarine"> 0.6,
  <"Iron (mg)","Oleomargarine"> 6,
  <"Vitamin A (KIU)","Oleomargarine"> 55.8,
  <"Vitamin B1 (mg)","Oleomargarine"> 0.2,
  <"Vitamin B2 (mg)","Oleomargarine"> 0,
  <"Niacin (mg)","Oleomargarine"> 0,
  <"Vitamin C (mg)","Oleomargarine"> 0,

  <"Calories (kcal)","Eggs"> 2.9,
  <"Protein (g)","Eggs"> 238,
  <"Calcium (g)","Eggs"> 1.0,
  <"Iron (mg)","Eggs"> 52,
  <"Vitamin A (KIU)","Eggs"> 18.6,
  <"Vitamin B1 (mg)","Eggs"> 2.8,
  <"Vitamin B2 (mg)","Eggs"> 6.5,
  <"Niacin (mg)","Eggs"> 1,
  <"Vitamin C (mg)","Eggs"> 0,

  <"Calories (kcal)","Cheese (Cheddar)"> 7.4,
  <"Protein (g)","Cheese (Cheddar)"> 448,
  <"Calcium (g)","Cheese (Cheddar)"> 16.4,
  <"Iron (mg)","Cheese (Cheddar)"> 19,
  <"Vitamin A (KIU)","Cheese (Cheddar)"> 28.1,
  <"Vitamin B1 (mg)","Cheese (Cheddar)"> 0.8,
  <"Vitamin B2 (mg)","Cheese (Cheddar)"> 10.3,
  <"Niacin (mg)","Cheese (Cheddar)"> 4,
  <"Vitamin C (mg)","Cheese (Cheddar)"> 0,

  <"Calories (kcal)","Cream"> 3.5,
  <"Protein (g)","Cream"> 49,
  <"Calcium (g)","Cream"> 1.7,
  <"Iron (mg)","Cream"> 3,
  <"Vitamin A (KIU)","Cream"> 16.9,
  <"Vitamin B1 (mg)","Cream"> 0.6,
  <"Vitamin B2 (mg)","Cream"> 2.5,
  <"Niacin (mg)","Cream"> 0,
  <"Vitamin C (mg)","Cream"> 17,

  <"Calories (kcal)","Peanut Butter"> 15.7,
  <"Protein (g)","Peanut Butter"> 661,
  <"Calcium (g)","Peanut Butter"> 1.0,
  <"Iron (mg)","Peanut Butter"> 48,
  <"Vitamin A (KIU)","Peanut Butter"> 0,
  <"Vitamin B1 (mg)","Peanut Butter"> 9.6,
  <"Vitamin B2 (mg)","Peanut Butter"> 8.1,
  <"Niacin (mg)","Peanut Butter"> 471,
  <"Vitamin C (mg)","Peanut Butter"> 0,

  <"Calories (kcal)","Mayonnaise"> 8.6,
  <"Protein (g)","Mayonnaise"> 18,
  <"Calcium (g)","Mayonnaise"> 0.2,
  <"Iron (mg)","Mayonnaise"> 8,
  <"Vitamin A (KIU)","Mayonnaise"> 2.7,
  <"Vitamin B1 (mg)","Mayonnaise"> 0.4,
  <"Vitamin B2 (mg)","Mayonnaise"> 0.5,
  <"Niacin (mg)","Mayonnaise"> 0,
  <"Vitamin C (mg)","Mayonnaise"> 0,

  <"Calories (kcal)","Crisco"> 20.1,
  <"Protein (g)","Crisco"> 0,
  <"Calcium (g)","Crisco"> 0,
  <"Iron (mg)","Crisco"> 0,
  <"Vitamin A (KIU)","Crisco"> 0,
  <"Vitamin B1 (mg)","Crisco"> 0,
  <"Vitamin B2 (mg)","Crisco"> 0,
  <"Niacin (mg)","Crisco"> 0,
  <"Vitamin C (mg)","Crisco"> 0,

  <"Calories (kcal)","Lard"> 41.7,
  <"Protein (g)","Lard"> 0,
  <"Calcium (g)","Lard"> 0,
  <"Iron (mg)","Lard"> 0,
  <"Vitamin A (KIU)","Lard"> 0.2,
  <"Vitamin B1 (mg)","Lard"> 0,
  <"Vitamin B2 (mg)","Lard"> 0.5,
  <"Niacin (mg)","Lard"> 5,
  <"Vitamin C (mg)","Lard"> 0,

  <"Calories (kcal)","Sirloin Steak"> 2.9,
  <"Protein (g)","Sirloin Steak"> 166,
  <"Calcium (g)","Sirloin Steak"> 0.1,
  <"Iron (mg)","Sirloin Steak"> 34,
  <"Vitamin A (KIU)","Sirloin Steak"> 0.2,
  <"Vitamin B1 (mg)","Sirloin Steak"> 2.1,
  <"Vitamin B2 (mg)","Sirloin Steak"> 2.9,
  <"Niacin (mg)","Sirloin Steak"> 69,
  <"Vitamin C (mg)","Sirloin Steak"> 0,

  <"Calories (kcal)","Round Steak"> 2.2,
  <"Protein (g)","Round Steak"> 214,
  <"Calcium (g)","Round Steak"> 0.1,
  <"Iron (mg)","Round Steak"> 32,
  <"Vitamin A (KIU)","Round Steak"> 0.4,
  <"Vitamin B1 (mg)","Round Steak"> 2.5,
  <"Vitamin B2 (mg)","Round Steak"> 2.4,
  <"Niacin (mg)","Round Steak"> 87,
  <"Vitamin C (mg)","Round Steak"> 0,

  <"Calories (kcal)","Rib Roast"> 3.4,
  <"Protein (g)","Rib Roast"> 213,
  <"Calcium (g)","Rib Roast"> 0.1,
  <"Iron (mg)","Rib Roast"> 33,
  <"Vitamin A (KIU)","Rib Roast"> 0,
  <"Vitamin B1 (mg)","Rib Roast"> 0,
  <"Vitamin B2 (mg)","Rib Roast"> 2,
  <"Niacin (mg)","Rib Roast"> 0,
  <"Vitamin C (mg)","Rib Roast"> 0,

  <"Calories (kcal)","Chuck Roast"> 3.6,
  <"Protein (g)","Chuck Roast"> 309,
  <"Calcium (g)","Chuck Roast"> 0.2,
  <"Iron (mg)","Chuck Roast"> 46,
  <"Vitamin A (KIU)","Chuck Roast"> 0.4,
  <"Vitamin B1 (mg)","Chuck Roast"> 1,
  <"Vitamin B2 (mg)","Chuck Roast"> 4,
  <"Niacin (mg)","Chuck Roast"> 120,
  <"Vitamin C (mg)","Chuck Roast"> 0,

  <"Calories (kcal)","Plate"> 8.5,
  <"Protein (g)","Plate"> 404,
  <"Calcium (g)","Plate"> 0.2,
  <"Iron (mg)","Plate"> 62,
  <"Vitamin A (KIU)","Plate"> 0,
  <"Vitamin B1 (mg)","Plate"> 0.9,
  <"Vitamin B2 (mg)","Plate"> 0,
  <"Niacin (mg)","Plate"> 0,
  <"Vitamin C (mg)","Plate"> 0,

  <"Calories (kcal)","Liver (Beef)"> 2.2,
  <"Protein (g)","Liver (Beef)"> 333,
  <"Calcium (g)","Liver (Beef)"> 0.2,
  <"Iron (mg)","Liver (Beef)"> 139,
  <"Vitamin A (KIU)","Liver (Beef)"> 169.2,
  <"Vitamin B1 (mg)","Liver (Beef)"> 6.4,
  <"Vitamin B2 (mg)","Liver (Beef)"> 50.8,
  <"Niacin (mg)","Liver (Beef)"> 316,
  <"Vitamin C (mg)","Liver (Beef)"> 525,

  <"Calories (kcal)","Leg of Lamb"> 3.1,
  <"Protein (g)","Leg of Lamb"> 245,
  <"Calcium (g)","Leg of Lamb"> 0.1,
  <"Iron (mg)","Leg of Lamb"> 20,
  <"Vitamin A (KIU)","Leg of Lamb"> 0,
  <"Vitamin B1 (mg)","Leg of Lamb"> 2.8,
  <"Vitamin B2 (mg)","Leg of Lamb"> 3.9,
  <"Niacin (mg)","Leg of Lamb"> 86,
  <"Vitamin C (mg)","Leg of Lamb"> 0,

  <"Calories (kcal)","Lamb Chops (Rib)"> 3.3,
  <"Protein (g)","Lamb Chops (Rib)"> 140,
  <"Calcium (g)","Lamb Chops (Rib)"> 0.1,
  <"Iron (mg)","Lamb Chops (Rib)"> 15,
  <"Vitamin A (KIU)","Lamb Chops (Rib)"> 0,
  <"Vitamin B1 (mg)","Lamb Chops (Rib)"> 1.7,
  <"Vitamin B2 (mg)","Lamb Chops (Rib)"> 2.7,
  <"Niacin (mg)","Lamb Chops (Rib)"> 54,
  <"Vitamin C (mg)","Lamb Chops (Rib)"> 0,

  <"Calories (kcal)","Pork Chops"> 3.5,
  <"Protein (g)","Pork Chops"> 196,
  <"Calcium (g)","Pork Chops"> 0.2,
  <"Iron (mg)","Pork Chops"> 30,
  <"Vitamin A (KIU)","Pork Chops"> 0,
  <"Vitamin B1 (mg)","Pork Chops"> 17.4,
  <"Vitamin B2 (mg)","Pork Chops"> 2.7,
  <"Niacin (mg)","Pork Chops"> 60,
  <"Vitamin C (mg)","Pork Chops"> 0,

  <"Calories (kcal)","Pork Loin Roast"> 4.4,
  <"Protein (g)","Pork Loin Roast"> 249,
  <"Calcium (g)","Pork Loin Roast"> 0.3,
  <"Iron (mg)","Pork Loin Roast"> 37,
  <"Vitamin A (KIU)","Pork Loin Roast"> 0,
  <"Vitamin B1 (mg)","Pork Loin Roast"> 18.2,
  <"Vitamin B2 (mg)","Pork Loin Roast"> 3.6,
  <"Niacin (mg)","Pork Loin Roast"> 79,
  <"Vitamin C (mg)","Pork Loin Roast"> 0,

  <"Calories (kcal)","Bacon"> 10.4,
  <"Protein (g)","Bacon"> 152,
  <"Calcium (g)","Bacon"> 0.2,
  <"Iron (mg)","Bacon"> 23,
  <"Vitamin A (KIU)","Bacon"> 0,
  <"Vitamin B1 (mg)","Bacon"> 1.8,
  <"Vitamin B2 (mg)","Bacon"> 1.8,
  <"Niacin (mg)","Bacon"> 71,
  <"Vitamin C (mg)","Bacon"> 0,

  <"Calories (kcal)","Ham, smoked"> 6.7,
  <"Protein (g)","Ham, smoked"> 212,
  <"Calcium (g)","Ham, smoked"> 0.2,
  <"Iron (mg)","Ham, smoked"> 31,
  <"Vitamin A (KIU)","Ham, smoked"> 0,
  <"Vitamin B1 (mg)","Ham, smoked"> 9.9,
  <"Vitamin B2 (mg)","Ham, smoked"> 3.3,
  <"Niacin (mg)","Ham, smoked"> 50,
  <"Vitamin C (mg)","Ham, smoked"> 0,

  <"Calories (kcal)","Salt Pork"> 18.8,
  <"Protein (g)","Salt Pork"> 164,
  <"Calcium (g)","Salt Pork"> 0.1,
  <"Iron (mg)","Salt Pork"> 26,
  <"Vitamin A (KIU)","Salt Pork"> 0,
  <"Vitamin B1 (mg)","Salt Pork"> 1.4,
  <"Vitamin B2 (mg)","Salt Pork"> 1.8,
  <"Niacin (mg)","Salt Pork"> 0,
  <"Vitamin C (mg)","Salt Pork"> 0,

  <"Calories (kcal)","Roasting Chicken"> 1.8,
  <"Protein (g)","Roasting Chicken"> 184,
  <"Calcium (g)","Roasting Chicken"> 0.1,
  <"Iron (mg)","Roasting Chicken"> 30,
  <"Vitamin A (KIU)","Roasting Chicken"> 0.1,
  <"Vitamin B1 (mg)","Roasting Chicken"> 0.9,
  <"Vitamin B2 (mg)","Roasting Chicken"> 1.8,
  <"Niacin (mg)","Roasting Chicken"> 68,
  <"Vitamin C (mg)","Roasting Chicken"> 46,

  <"Calories (kcal)","Veal Cutlets"> 1.7,
  <"Protein (g)","Veal Cutlets"> 156,
  <"Calcium (g)","Veal Cutlets"> 0.1,
  <"Iron (mg)","Veal Cutlets"> 24,
  <"Vitamin A (KIU)","Veal Cutlets"> 0,
  <"Vitamin B1 (mg)","Veal Cutlets"> 1.4,
  <"Vitamin B2 (mg)","Veal Cutlets"> 2.4,
  <"Niacin (mg)","Veal Cutlets"> 57,
  <"Vitamin C (mg)","Veal Cutlets"> 0,

  <"Calories (kcal)","Salmon, Pink (can)"> 5.8,
  <"Protein (g)","Salmon, Pink (can)"> 705,
  <"Calcium (g)","Salmon, Pink (can)"> 6.8,
  <"Iron (mg)","Salmon, Pink (can)"> 45,
  <"Vitamin A (KIU)","Salmon, Pink (can)"> 3.5,
  <"Vitamin B1 (mg)","Salmon, Pink (can)"> 1,
  <"Vitamin B2 (mg)","Salmon, Pink (can)"> 4.9,
  <"Niacin (mg)","Salmon, Pink (can)"> 209,
  <"Vitamin C (mg)","Salmon, Pink (can)"> 0,

  <"Calories (kcal)","Apples"> 5.8,
  <"Protein (g)","Apples"> 27,
  <"Calcium (g)","Apples"> 0.5,
  <"Iron (mg)","Apples"> 36,
  <"Vitamin A (KIU)","Apples"> 7.3,
  <"Vitamin B1 (mg)","Apples"> 3.6,
  <"Vitamin B2 (mg)","Apples"> 2.7,
  <"Niacin (mg)","Apples"> 5,
  <"Vitamin C (mg)","Apples"> 544,

  <"Calories (kcal)","Bananas"> 4.9,
  <"Protein (g)","Bananas"> 60,
  <"Calcium (g)","Bananas"> 0.4,
  <"Iron (mg)","Bananas"> 30,
  <"Vitamin A (KIU)","Bananas"> 17.4,
  <"Vitamin B1 (mg)","Bananas"> 2.5,
  <"Vitamin B2 (mg)","Bananas"> 3.5,
  <"Niacin (mg)","Bananas"> 28,
  <"Vitamin C (mg)","Bananas"> 498,

  <"Calories (kcal)","Lemons"> 1.0,
  <"Protein (g)","Lemons"> 21,
  <"Calcium (g)","Lemons"> 0.5,
  <"Iron (mg)","Lemons"> 14,
  <"Vitamin A (KIU)","Lemons"> 0,
  <"Vitamin B1 (mg)","Lemons"> 0.5,
  <"Vitamin B2 (mg)","Lemons"> 0,
  <"Niacin (mg)","Lemons"> 4,
  <"Vitamin C (mg)","Lemons"> 952,

  <"Calories (kcal)","Oranges"> 2.2,
  <"Protein (g)","Oranges"> 40,
  <"Calcium (g)","Oranges"> 1.1,
  <"Iron (mg)","Oranges"> 18,
  <"Vitamin A (KIU)","Oranges"> 11.1,
  <"Vitamin B1 (mg)","Oranges"> 3.6,
  <"Vitamin B2 (mg)","Oranges"> 1.3,
  <"Niacin (mg)","Oranges"> 10,
  <"Vitamin C (mg)","Oranges"> 1998,

  <"Calories (kcal)","Green Beans"> 2.4,
  <"Protein (g)","Green Beans"> 138,
  <"Calcium (g)","Green Beans"> 3.7,
  <"Iron (mg)","Green Beans"> 80,
  <"Vitamin A (KIU)","Green Beans"> 69,
  <"Vitamin B1 (mg)","Green Beans"> 4.3,
  <"Vitamin B2 (mg)","Green Beans"> 5.8,
  <"Niacin (mg)","Green Beans"> 37,
  <"Vitamin C (mg)","Green Beans"> 862,

  <"Calories (kcal)","Cabbage"> 2.6,
  <"Protein (g)","Cabbage"> 125,
  <"Calcium (g)","Cabbage"> 4.0,
  <"Iron (mg)","Cabbage"> 36,
  <"Vitamin A (KIU)","Cabbage"> 7.2,
  <"Vitamin B1 (mg)","Cabbage"> 9,
  <"Vitamin B2 (mg)","Cabbage"> 4.5,
  <"Niacin (mg)","Cabbage"> 26,
  <"Vitamin C (mg)","Cabbage"> 5369,

  <"Calories (kcal)","Carrots"> 2.7,
  <"Protein (g)","Carrots"> 73,
  <"Calcium (g)","Carrots"> 2.8,
  <"Iron (mg)","Carrots"> 43,
  <"Vitamin A (KIU)","Carrots"> 188.5,
  <"Vitamin B1 (mg)","Carrots"> 6.1,
  <"Vitamin B2 (mg)","Carrots"> 4.3,
  <"Niacin (mg)","Carrots"> 89,
  <"Vitamin C (mg)","Carrots"> 608,

  <"Calories (kcal)","Celery"> 0.9,
  <"Protein (g)","Celery"> 51,
  <"Calcium (g)","Celery"> 3.0,
  <"Iron (mg)","Celery"> 23,
  <"Vitamin A (KIU)","Celery"> 0.9,
  <"Vitamin B1 (mg)","Celery"> 1.4,
  <"Vitamin B2 (mg)","Celery"> 1.4,
  <"Niacin (mg)","Celery"> 9,
  <"Vitamin C (mg)","Celery"> 313,

  <"Calories (kcal)","Lettuce"> 0.4,
  <"Protein (g)","Lettuce"> 27,
  <"Calcium (g)","Lettuce"> 1.1,
  <"Iron (mg)","Lettuce"> 22,
  <"Vitamin A (KIU)","Lettuce"> 112.4,
  <"Vitamin B1 (mg)","Lettuce"> 1.8,
  <"Vitamin B2 (mg)","Lettuce"> 3.4,
  <"Niacin (mg)","Lettuce"> 11,
  <"Vitamin C (mg)","Lettuce"> 449,

  <"Calories (kcal)","Onions"> 5.8,
  <"Protein (g)","Onions"> 166,
  <"Calcium (g)","Onions"> 3.8,
  <"Iron (mg)","Onions"> 59,
  <"Vitamin A (KIU)","Onions"> 16.6,
  <"Vitamin B1 (mg)","Onions"> 4.7,
  <"Vitamin B2 (mg)","Onions"> 5.9,
  <"Niacin (mg)","Onions"> 21,
  <"Vitamin C (mg)","Onions"> 1184,

  <"Calories (kcal)","Potatoes"> 14.3,
  <"Protein (g)","Potatoes"> 336,
  <"Calcium (g)","Potatoes"> 1.8,
  <"Iron (mg)","Potatoes"> 118,
  <"Vitamin A (KIU)","Potatoes"> 6.7,
  <"Vitamin B1 (mg)","Potatoes"> 29.4,
  <"Vitamin B2 (mg)","Potatoes"> 7.1,
  <"Niacin (mg)","Potatoes"> 198,
  <"Vitamin C (mg)","Potatoes"> 2522,

  <"Calories (kcal)","Spinach"> 1.1,
  <"Protein (g)","Spinach"> 106,
  <"Calcium (g)","Spinach"> 0,
  <"Iron (mg)","Spinach"> 138,
  <"Vitamin A (KIU)","Spinach"> 918.4,
  <"Vitamin B1 (mg)","Spinach"> 5.7,
  <"Vitamin B2 (mg)","Spinach"> 13.8,
  <"Niacin (mg)","Spinach"> 33,
  <"Vitamin C (mg)","Spinach"> 2755,

  <"Calories (kcal)","Sweet Potatoes"> 9.6,
  <"Protein (g)","Sweet Potatoes"> 138,
  <"Calcium (g)","Sweet Potatoes"> 2.7,
  <"Iron (mg)","Sweet Potatoes"> 54,
  <"Vitamin A (KIU)","Sweet Potatoes"> 290.7,
  <"Vitamin B1 (mg)","Sweet Potatoes"> 8.4,
  <"Vitamin B2 (mg)","Sweet Potatoes"> 5.4,
  <"Niacin (mg)","Sweet Potatoes"> 83,
  <"Vitamin C (mg)","Sweet Potatoes"> 1912,

  <"Calories (kcal)","Peaches (can)"> 3.7,
  <"Protein (g)","Peaches (can)"> 20,
  <"Calcium (g)","Peaches (can)"> 0.4,
  <"Iron (mg)","Peaches (can)"> 10,
  <"Vitamin A (KIU)","Peaches (can)"> 21.5,
  <"Vitamin B1 (mg)","Peaches (can)"> 0.5,
  <"Vitamin B2 (mg)","Peaches (can)"> 1,
  <"Niacin (mg)","Peaches (can)"> 31,
  <"Vitamin C (mg)","Peaches (can)"> 196,

  <"Calories (kcal)","Pears (can)"> 3.0,
  <"Protein (g)","Pears (can)"> 8,
  <"Calcium (g)","Pears (can)"> 0.3,
  <"Iron (mg)","Pears (can)"> 8,
  <"Vitamin A (KIU)","Pears (can)"> 0.8,
  <"Vitamin B1 (mg)","Pears (can)"> 0.8,
  <"Vitamin B2 (mg)","Pears (can)"> 0.8,
  <"Niacin (mg)","Pears (can)"> 5,
  <"Vitamin C (mg)","Pears (can)"> 81,

  <"Calories (kcal)","Pineapple (can)"> 2.4,
  <"Protein (g)","Pineapple (can)"> 16,
  <"Calcium (g)","Pineapple (can)"> 0.4,
  <"Iron (mg)","Pineapple (can)"> 8,
  <"Vitamin A (KIU)","Pineapple (can)"> 2,
  <"Vitamin B1 (mg)","Pineapple (can)"> 2.8,
  <"Vitamin B2 (mg)","Pineapple (can)"> 0.8,
  <"Niacin (mg)","Pineapple (can)"> 7,
  <"Vitamin C (mg)","Pineapple (can)"> 399,

  <"Calories (kcal)","Asparagus (can)"> 0.4,
  <"Protein (g)","Asparagus (can)"> 33,
  <"Calcium (g)","Asparagus (can)"> 0.3,
  <"Iron (mg)","Asparagus (can)"> 12,
  <"Vitamin A (KIU)","Asparagus (can)"> 16.3,
  <"Vitamin B1 (mg)","Asparagus (can)"> 1.4,
  <"Vitamin B2 (mg)","Asparagus (can)"> 2.1,
  <"Niacin (mg)","Asparagus (can)"> 17,
  <"Vitamin C (mg)","Asparagus (can)"> 272,

  <"Calories (kcal)","Green Beans (can)"> 1.0,
  <"Protein (g)","Green Beans (can)"> 54,
  <"Calcium (g)","Green Beans (can)"> 2,
  <"Iron (mg)","Green Beans (can)"> 65,
  <"Vitamin A (KIU)","Green Beans (can)"> 53.9,
  <"Vitamin B1 (mg)","Green Beans (can)"> 1.6,
  <"Vitamin B2 (mg)","Green Beans (can)"> 4.3,
  <"Niacin (mg)","Green Beans (can)"> 32,
  <"Vitamin C (mg)","Green Beans (can)"> 431,

  <"Calories (kcal)","Pork and Beans (can)"> 7.5,
  <"Protein (g)","Pork and Beans (can)"> 364,
  <"Calcium (g)","Pork and Beans (can)"> 4,
  <"Iron (mg)","Pork and Beans (can)"> 134,
  <"Vitamin A (KIU)","Pork and Beans (can)"> 3.5,
  <"Vitamin B1 (mg)","Pork and Beans (can)"> 8.3,
  <"Vitamin B2 (mg)","Pork and Beans (can)"> 7.7,
  <"Niacin (mg)","Pork and Beans (can)"> 56,
  <"Vitamin C (mg)","Pork and Beans (can)"> 0,

  <"Calories (kcal)","Corn (can)"> 5.2,
  <"Protein (g)","Corn (can)"> 136,
  <"Calcium (g)","Corn (can)"> 0.2,
  <"Iron (mg)","Corn (can)"> 16,
  <"Vitamin A (KIU)","Corn (can)"> 12,
  <"Vitamin B1 (mg)","Corn (can)"> 1.6,
  <"Vitamin B2 (mg)","Corn (can)"> 2.7,
  <"Niacin (mg)","Corn (can)"> 42,
  <"Vitamin C (mg)","Corn (can)"> 218,

  <"Calories (kcal)","Peas (can)"> 2.3,
  <"Protein (g)","Peas (can)"> 136,
  <"Calcium (g)","Peas (can)"> 0.6,
  <"Iron (mg)","Peas (can)"> 45,
  <"Vitamin A (KIU)","Peas (can)"> 34.9,
  <"Vitamin B1 (mg)","Peas (can)"> 4.9,
  <"Vitamin B2 (mg)","Peas (can)"> 2.5,
  <"Niacin (mg)","Peas (can)"> 37,
  <"Vitamin C (mg)","Peas (can)"> 370,

  <"Calories (kcal)","Tomatoes (can)"> 1.3,
  <"Protein (g)","Tomatoes (can)"> 63,
  <"Calcium (g)","Tomatoes (can)"> 0.7,
  <"Iron (mg)","Tomatoes (can)"> 38,
  <"Vitamin A (KIU)","Tomatoes (can)"> 53.2,
  <"Vitamin B1 (mg)","Tomatoes (can)"> 3.4,
  <"Vitamin B2 (mg)","Tomatoes (can)"> 2.5,
  <"Niacin (mg)","Tomatoes (can)"> 36,
  <"Vitamin C (mg)","Tomatoes (can)"> 1253,

  <"Calories (kcal)","Tomato Soup (can)"> 1.6,
  <"Protein (g)","Tomato Soup (can)"> 71,
  <"Calcium (g)","Tomato Soup (can)"> 0.6,
  <"Iron (mg)","Tomato Soup (can)"> 43,
  <"Vitamin A (KIU)","Tomato Soup (can)"> 57.9,
  <"Vitamin B1 (mg)","Tomato Soup (can)"> 3.5,
  <"Vitamin B2 (mg)","Tomato Soup (can)"> 2.4,
  <"Niacin (mg)","Tomato Soup (can)"> 67,
  <"Vitamin C (mg)","Tomato Soup (can)"> 862,

  <"Calories (kcal)","Peaches, Dried"> 8.5,
  <"Protein (g)","Peaches, Dried"> 87,
  <"Calcium (g)","Peaches, Dried"> 1.7,
  <"Iron (mg)","Peaches, Dried"> 173,
  <"Vitamin A (KIU)","Peaches, Dried"> 86.8,
  <"Vitamin B1 (mg)","Peaches, Dried"> 1.2,
  <"Vitamin B2 (mg)","Peaches, Dried"> 4.3,
  <"Niacin (mg)","Peaches, Dried"> 55,
  <"Vitamin C (mg)","Peaches, Dried"> 57,

  <"Calories (kcal)","Prunes, Dried"> 12.8,
  <"Protein (g)","Prunes, Dried"> 99,
  <"Calcium (g)","Prunes, Dried"> 2.5,
  <"Iron (mg)","Prunes, Dried"> 154,
  <"Vitamin A (KIU)","Prunes, Dried"> 85.7,
  <"Vitamin B1 (mg)","Prunes, Dried"> 3.9,
  <"Vitamin B2 (mg)","Prunes, Dried"> 4.3,
  <"Niacin (mg)","Prunes, Dried"> 65,
  <"Vitamin C (mg)","Prunes, Dried"> 257,

  <"Calories (kcal)","Raisins, Dried"> 13.5,
  <"Protein (g)","Raisins, Dried"> 104,
  <"Calcium (g)","Raisins, Dried"> 2.5,
  <"Iron (mg)","Raisins, Dried"> 136,
  <"Vitamin A (KIU)","Raisins, Dried"> 4.5,
  <"Vitamin B1 (mg)","Raisins, Dried"> 6.3,
  <"Vitamin B2 (mg)","Raisins, Dried"> 1.4,
  <"Niacin (mg)","Raisins, Dried"> 24,
  <"Vitamin C (mg)","Raisins, Dried"> 136,

  <"Calories (kcal)","Peas, Dried"> 20.0,
  <"Protein (g)","Peas, Dried"> 1367,
  <"Calcium (g)","Peas, Dried"> 4.2,
  <"Iron (mg)","Peas, Dried"> 345,
  <"Vitamin A (KIU)","Peas, Dried"> 2.9,
  <"Vitamin B1 (mg)","Peas, Dried"> 28.7,
  <"Vitamin B2 (mg)","Peas, Dried"> 18.4,
  <"Niacin (mg)","Peas, Dried"> 162,
  <"Vitamin C (mg)","Peas, Dried"> 0,

  <"Calories (kcal)","Lima Beans, Dried"> 17.4,
  <"Protein (g)","Lima Beans, Dried"> 1055,
  <"Calcium (g)","Lima Beans, Dried"> 3.7,
  <"Iron (mg)","Lima Beans, Dried"> 459,
  <"Vitamin A (KIU)","Lima Beans, Dried"> 5.1,
  <"Vitamin B1 (mg)","Lima Beans, Dried"> 26.9,
  <"Vitamin B2 (mg)","Lima Beans, Dried"> 38.2,
  <"Niacin (mg)","Lima Beans, Dried"> 93,
  <"Vitamin C (mg)","Lima Beans, Dried"> 0,

  <"Calories (kcal)","Navy Beans, Dried"> 26.9,
  <"Protein (g)","Navy Beans, Dried"> 1691,
  <"Calcium (g)","Navy Beans, Dried"> 11.4,
  <"Iron (mg)","Navy Beans, Dried"> 792,
  <"Vitamin A (KIU)","Navy Beans, Dried"> 0,
  <"Vitamin B1 (mg)","Navy Beans, Dried"> 38.4,
  <"Vitamin B2 (mg)","Navy Beans, Dried"> 24.6,
  <"Niacin (mg)","Navy Beans, Dried"> 217,
  <"Vitamin C (mg)","Navy Beans, Dried"> 0,

  <"Calories (kcal)","Coffee"> 0,
  <"Protein (g)","Coffee"> 0,
  <"Calcium (g)","Coffee"> 0,
  <"Iron (mg)","Coffee"> 0,
  <"Vitamin A (KIU)","Coffee"> 0,
  <"Vitamin B1 (mg)","Coffee"> 4,
  <"Vitamin B2 (mg)","Coffee"> 5.1,
  <"Niacin (mg)","Coffee"> 50,
  <"Vitamin C (mg)","Coffee"> 0,

  <"Calories (kcal)","Tea"> 0,
  <"Protein (g)","Tea"> 0,
  <"Calcium (g)","Tea"> 0,
  <"Iron (mg)","Tea"> 0,
  <"Vitamin A (KIU)","Tea"> 0,
  <"Vitamin B1 (mg)","Tea"> 0,
  <"Vitamin B2 (mg)","Tea"> 2.3,
  <"Niacin (mg)","Tea"> 42,
  <"Vitamin C (mg)","Tea"> 0,

  <"Calories (kcal)","Cocoa"> 8.7,
  <"Protein (g)","Cocoa"> 237,
  <"Calcium (g)","Cocoa"> 3,
  <"Iron (mg)","Cocoa"> 72,
  <"Vitamin A (KIU)","Cocoa"> 0,
  <"Vitamin B1 (mg)","Cocoa"> 2,
  <"Vitamin B2 (mg)","Cocoa"> 11.9,
  <"Niacin (mg)","Cocoa"> 40,
  <"Vitamin C (mg)","Cocoa"> 0,

  <"Calories (kcal)","Chocolate"> 8.0,
  <"Protein (g)","Chocolate"> 77,
  <"Calcium (g)","Chocolate"> 1.3,
  <"Iron (mg)","Chocolate"> 39,
  <"Vitamin A (KIU)","Chocolate"> 0,
  <"Vitamin B1 (mg)","Chocolate"> 0.9,
  <"Vitamin B2 (mg)","Chocolate"> 3.4,
  <"Niacin (mg)","Chocolate"> 14,
  <"Vitamin C (mg)","Chocolate"> 0,

  <"Calories (kcal)","Sugar"> 34.9,
  <"Protein (g)","Sugar"> 0,
  <"Calcium (g)","Sugar"> 0,
  <"Iron (mg)","Sugar"> 0,
  <"Vitamin A (KIU)","Sugar"> 0,
  <"Vitamin B1 (mg)","Sugar"> 0,
  <"Vitamin B2 (mg)","Sugar"> 0,
  <"Niacin (mg)","Sugar"> 0,
  <"Vitamin C (mg)","Sugar"> 0,

  <"Calories (kcal)","Corn Syrup"> 14.7,
  <"Protein (g)","Corn Syrup"> 0,
  <"Calcium (g)","Corn Syrup"> 0.5,
  <"Iron (mg)","Corn Syrup"> 74,
  <"Vitamin A (KIU)","Corn Syrup"> 0,
  <"Vitamin B1 (mg)","Corn Syrup"> 0,
  <"Vitamin B2 (mg)","Corn Syrup"> 0,
  <"Niacin (mg)","Corn Syrup"> 5,
  <"Vitamin C (mg)","Corn Syrup"> 0,

  <"Calories (kcal)","Molasses"> 9.0,
  <"Protein (g)","Molasses"> 0,
  <"Calcium (g)","Molasses"> 10.3,
  <"Iron (mg)","Molasses"> 244,
  <"Vitamin A (KIU)","Molasses"> 0,
  <"Vitamin B1 (mg)","Molasses"> 1.9,
  <"Vitamin B2 (mg)","Molasses"> 7.5,
  <"Niacin (mg)","Molasses"> 146,
  <"Vitamin C (mg)","Molasses"> 0,

  <"Calories (kcal)","Strawberry Preserves"> 6.4,
  <"Protein (g)","Strawberry Preserves"> 11,
  <"Calcium (g)","Strawberry Preserves"> 0.4,
  <"Iron (mg)","Strawberry Preserves"> 7,
  <"Vitamin A (KIU)","Strawberry Preserves"> 0.2,
  <"Vitamin B1 (mg)","Strawberry Preserves"> 0.2,
  <"Vitamin B2 (mg)","Strawberry Preserves"> 0.4,
  <"Niacin (mg)","Strawberry Preserves"> 3,
  <"Vitamin C (mg)","Strawberry Preserves"> 0
];
'''

# %% [markdown]
# ## Solving Stigler's Diet Problem with PyOPL

# %%
# %%capture
! pip install rhetor

# %%
from pyopl import solve

stigler_file_model = "stigler.mod"
stigler_file_data = "stigler.dat"

with open(stigler_file_model, "w") as f:
    f.write(pyopl_model)

with open(stigler_file_data, "w") as f:
    f.write(pyopl_data)

results = solve(stigler_file_model, stigler_file_data)
# Out:
# PyOPL: compiling model...
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# PyOPL/Gurobi: variables=86, constraints=0, sense=1
# Gurobi Optimizer version 13.0.2 build v13.0.2rc1 (mac64[arm] - Darwin 25.6.0 25G83)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 18 rows, 86 columns and 1149 nonzeros (Min)
# Model fingerprint: 0xf06ca84a
# Model has 77 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 8e+01]
#
# Presolve removed 9 rows and 59 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 27 columns, 213 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.408750e+01   0.000000e+00      0s
#        5    3.9661732e+01   0.000000e+00   0.000000e+00      0s
#
# ...

# %% [markdown]
# ## Solution to Sigler's Diet Problem

# %%
solution = results["solution"]
selected_foods = {
    variable_name[2:-1]: value
    for variable_name, value in solution.items()
    if variable_name.startswith("x[") and value > 1e-9
}

food_column_width = max(map(len, selected_foods), default=4)
print("Selected foods and annual cost")
print(f"{'Food':<{food_column_width}}  Cost")
print(f"{'-' * food_column_width}  --------")

for food, cost in selected_foods.items():
    print(f"{food:<{food_column_width}}  ${cost:,.2f}")

print(f"\nTotal cost: ${results['objective_value']:,.2f} per year")
# Out:
# Selected foods and annual cost
# Food                    Cost
# ----------------------  --------
# Wheat Flour (Enriched)  $10.77
# Liver (Beef)            $0.69
# Cabbage                 $4.09
# Spinach                 $1.83
# Navy Beans, Dried       $22.28
#
# Total cost: $39.66 per year

# %% [markdown]
# ## References
#
# Dantzig, G. B. (1990). The diet problem. Interfaces, 20(4), 43–47. doi:10.1287/inte.20.4.43
#
# Garille, S. G., & Gass, S. I. (2001). Stigler’s diet problem revisited. Operations Research, 49(1), 1–13. doi:10.1287/opre.49.1.1.11187
#
# https://developers.google.com/optimization/lp/stigler_diet
